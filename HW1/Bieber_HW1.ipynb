# %% [markdown]
# <a href="https://colab.research.google.com/github/jarrodsb/PHYS_313/blob/main/HW1/Bieber_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PHYS 313 - Homework 1
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import constants

# %% [markdown]
# ### Load Data from GitHub Text Files
#
# Please replace the placeholder URLs with the actual raw URLs of your text files from the GitHub repository. You can usually get the raw URL by navigating to the file on GitHub and clicking the 'Raw' button.

# %%
# Replace these with the actual raw URLs of your files
file1_url = 'https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/path/to/your_file1.txt'
file2_url = 'https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/path/to/your_file2.txt'

# Assuming the text files are structured like CSVs with space or comma delimiters.
# Adjust 'sep' and 'header' as needed based on your file format.
# For example, if it's space-separated, use sep='\s+'

try:
    df1 = pd.read_csv(file1_url, sep='\s+', header=None)
    df2 = pd.read_csv(file2_url, sep='\s+', header=None)

    print("--- Data from file1.txt ---")
    display(df1.head())
    print("\n--- Data from file2.txt ---")
    display(df2.head())

except Exception as e:
    print(f"Error loading files: {e}")
    print("Please ensure the URLs are correct and accessible, and adjust `sep` and `header` parameters if needed.")

# %%
sine_waves = pd.read_csv('https://raw.githubusercontent.com/jarrodsb/PHYS_313/refs/heads/main/HW1/sine_waves.txt', sep=r'\s+')
two_Gauss = pd.read_csv('https://raw.githubusercontent.com/jarrodsb/PHYS_313/refs/heads/main/HW1/two_Gauss.txt', sep='\t')

# Remove any columns that start with 'Unnamed' (these are typically empty or parsing artifacts)
two_Gauss = two_Gauss.loc[:, ~two_Gauss.columns.str.contains('^Unnamed')]

display(sine_waves.head())
display(two_Gauss.head())
# Out:
#    Distance[mm]       t=0       sec  t=1sec
# 0             0  0.000000  2.945148     NaN
# 1             1  1.145181  3.401783     NaN
# 2             2  2.164294  3.483928     NaN
# 3             3  2.945148  3.182541     NaN
# 4             4  3.401783  2.530801     NaN
#    Position[cm]  Wave at 1 sec  Wave at 3 sec
# 0           0.1   4.789548e-11            0.0
# 1           0.2   7.392279e-11            0.0
# 2           0.3   1.136384e-10            0.0
# 3           0.4   1.739941e-10            0.0
# 4           0.5   2.653424e-10            0.0
